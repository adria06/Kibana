# %% [markdown]
# # Interactic Visualization using ElasticSearch Stack
#
# **Objectives:**
#  - Create interactive graphs using Kibana
#
# Tutorial video: https://youtu.be/gQ1c1uILyKI
#
#
# ## Exercise 1: Download Kibana and show some graphs using sample data
#
# We install Elastic Search and iniciate it from the root:
# C:\Program Files\elasticsearch-8.1.2\bin\elasticsearch.bat
#
# Then in the browser we run https://localhost:9200/
#
# When the brower shows the following means that Elastic Search has been installed correctly

# %% [markdown]
# ![Capture-2.PNG](attachment:Capture-2.PNG)

# %% [markdown]
# Now we install Kibana and run the file C:\Program Files\kibana-8.1.2\bin\kibana.bat
#
# The in the brower we run http://localhost:5601/
#
# Then we upload the sample data "Sample web logs" and create some graphs
#
# We upload the 'kibana_sample_data_ecommerce' and create some graphs

# %% [markdown]
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ![Capture3.PNG](attachment:Capture3.PNG)

# %% [markdown]
# ![Capture4.PNG](attachment:Capture4.PNG)

# %% [markdown]
# ![Capture5.PNG](attachment:Capture5.PNG)

# %% [markdown]
# ## Exercise 2 - Create a Interactive Dashboard using sample data.
#
# Dashboard link http://localhost:5601/app/r/s/famous-warm-electrician
#
# Some scenshots of the Dashboard

# %% [markdown]
# ![Dashboard1.PNG](attachment:Dashboard1.PNG)

# %% [markdown]
# ![Dashboard2.PNG](attachment:Dashboard2.PNG)

# %% [markdown]
# ![Dashboard3.PNG](attachment:Dashboard3.PNG)

# %% [markdown]
# ## Exercise 3 - Create a dashboard using some different types offered by Kibana
#
# We create a dashboard using the graphs from the exercise 1 from the datasheet 'kibana_sample_data_ecommerce'
#
# Dashboard http://localhost:5601/app/r/s/shaggy-moldy-megabyte
#
# Dashboard screenshots

# %% [markdown]
# ![Dash1.PNG](attachment:Dash1.PNG)

# %% [markdown]
# ![Dash2.PNG](attachment:Dash2.PNG)

# %% [markdown]
# ![Dash3.PNG](attachment:Dash3.PNG)
